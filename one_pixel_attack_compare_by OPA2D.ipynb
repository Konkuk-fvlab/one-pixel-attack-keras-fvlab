# %%
# If running in Google Colab, import files
# !pip install numpy pandas scipy matplotlib tensorflow-gpu keras tqdm
try:
    import google.colab
    in_colab = True
except:
    in_colab = False

if in_colab:
    # !git clone https://github.com/Hyperparticle/one-pixel-attack-keras.git
    # !mv -v one-pixel-attack-keras/* .
    # !rm -rf one-pixel-attack-keras

# Python Libraries
# %matplotlib inline
import os
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import math
from keras.datasets import cifar10
from keras import backend as K # original
#from kears import keras.backend.tensorflow_backend as K
import tensorflow as tf
from PIL import Image
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib

# Custom Networks
from networks.lenet import LeNet
from networks.pure_cnn import PureCnn
from networks.network_in_network import NetworkInNetwork
from networks.resnet import ResNet
from networks.densenet import DenseNet
from networks.wide_resnet import WideResNet
from networks.capsnet import CapsNet

# Helper functions
from differential_evolution import differential_evolution
import helper

matplotlib.style.use('ggplot')
np.random.seed(100)

# %% [markdown]
# ## Imports

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ## Image Perturbation

# %%
def perturb_image(xs, img):
    # If this function is passed just one perturbation vector,
    # pack it in a list to keep the computation the same
    if xs.ndim < 2:
        xs = np.array([xs])
    
    # Copy the image n == len(xs) times so that we can 
    # create n new perturbed images
    tile = [len(xs)] + [1]*(xs.ndim+1)
    imgs = np.tile(img, tile)
    # numpy tile(A, repeat_shape)
    # A라는 array가 repeat_shape 모양으로 쌓이도록
    # 추후에 다시 보자..
    
    # Make sure to floor the members of xs as int types
    xs = xs.astype(int)
    
    for x,img in zip(xs, imgs):
        # Split x into an array of 5-tuples (perturbation pixels)
        # i.e., [[x,y,r,g,b], ...]
        pixels = np.split(x, len(x) // 5)
        # pixels = 5-tuple of perturb information (x,y,r,g,b) by kyle
        for pixel in pixels:
            # At each pixel's x,y position, assign its rgb value
            x_pos, y_pos, *rgb = pixel # *rgb = 뒤에 올 (r,g,b) 값을 가리킨다
            img[x_pos, y_pos] = rgb # perturb image by *rgb == (r,g,b) by kyle
    
    return imgs
    # Return value is array of perturbed images by xs
    # For example, if xs is [(16,16,255,255,0), (16,16,0,255,255)]
    # imgs is an array of perturbed image by xs[0], xs[1]. So it's size is 2 by kyle

# %% [markdown]
# ## Load Model

# %%
lenet = LeNet()
resnet = ResNet()

# originally, lenet and resnet

## Uncomment below to load more models to play with. Make sure the model files exist by training or downloading them.

# lenet = LeNet()
pure_cnn = PureCnn()
net_in_net = NetworkInNetwork()
# resnet = ResNet()
densenet = DenseNet()
wide_resnet = WideResNet()
# capsnet = CapsNet()
# models = [lenet, resnet, wide_resnet]

models = [lenet, pure_cnn, net_in_net, resnet, densenet, wide_resnet]
# Out:
# Successfully loaded lenet
# Successfully loaded resnet
# Successfully loaded pure_cnn
# Successfully loaded net_in_net
# Successfully loaded densenet
# Successfully loaded wide_resnet

# %%
def predict_classes(xs, img, target_class, model, minimize=True):
    # Perturb the image with the given pixel(s) x and get the prediction of the model
    imgs_perturbed = perturb_image(xs, img)
    predictions = model.predict(imgs_perturbed)[:,target_class]
    # Target class의 값만 뽑아내는 용(파이썬 문법)
    # This function should always be minimized, so return its complement if needed
    return predictions if minimize else 1 - predictions

# %% [markdown]
# ## OPA2D ATTACK

# %%
# This cell is for OPA2D_Attack.

def Algorithm1(image_id, model, sensitive_list):
    
    #sensitive_pixel = sensitive_pixel_sorting(image_id)
    #print(sensitive_pixel)
    x_success = None
    L_opt = 256

    for pixel in sensitive_list:
        L_opt = 256
        print("pixel coordinate : " + str(pixel[0]) + ", " + str(pixel[1]))
        img = x_test[image_id].copy()
        x_pos = pixel[0]
        y_pos = pixel[1]
        r_xk = img[x_pos][y_pos][0]
        g_xk = img[x_pos][y_pos][1]
        b_xk = img[x_pos][y_pos][2]

        a_max = L_opt-1
        a_min = 1
        x_prime = None
        x = [x_pos, y_pos, r_xk, g_xk, b_xk]
        while a_min <= a_max:
            # difference with pseudo code, we have found an error of code, - -> + (minus to plus)
            a = (a_max + a_min) // 2
            R_xk_bounds = [(bound(r_xk - a), bound(r_xk+a)), (bound(g_xk-a), bound(g_xk+a)), (bound(b_xk-a), bound(b_xk+a))]

            x_prime, success = opa2d_attack(image_id, model, R_xk_bounds, x_pos, y_pos)
            print("alpha : ", a)
            print("alpha_min : ", a_min)
            if success:
                L_opt = dist(x,x_prime)
                a_max = L_opt-1
                x_success = x_prime
            else:
                a_min = a_min + a + 1

    if(L_opt < 256):
        return (x_success,"attack success")
    else:
        return (x_success,"attack failed")
    
def dist(x, x_prime):
    return max(abs(x[2] - x_prime[2]), abs(x[3] - x_prime[3]), abs(x[4] - x_prime[4]))

def bound(num):
    return max(0, min(255,num))

def opa2d_attack(img_id, model, R_xk_bounds, x_pos, y_pos, target=None, pixel_count=1, maxiter=5, popsize=50, verbose=False):
    # Change the target class based on whether this is a targeted attack or not
    targeted_attack = target is not None
    target_class = target if targeted_attack else y_test[img_id, 0]
    
    # Define bounds for a flat vector of x,y,r,g,b values
    # For more pixels, repeat this layout
    bounds = [(x_pos, x_pos), (y_pos, y_pos), R_xk_bounds[0], R_xk_bounds[1], R_xk_bounds[2]] * pixel_count

    # Population multiplier, in terms of the size of the perturbation vector x
    popmul = max(1, popsize // len(bounds))
    
    # Format the predict/callback functions for the differential evolution algorithm
    def predict_fn(xs):
        return predict_classes(xs, x_test[img_id], target_class, 
                               model, target is None)
    
    def callback_fn(x, convergence):
        return attack_success(x, x_test[img_id], target_class, 
                              model, targeted_attack, verbose)
    
    # Call Scipy's Implementation of Differential Evolution
    attack_result = differential_evolution(
        predict_fn, bounds, maxiter=maxiter, popsize=popmul,
        recombination=1, atol=-1, callback=callback_fn, polish=False)
    
    # Calculate some useful statistics to return from this function
    attack_image = perturb_image(attack_result.x, x_test[img_id])[0]
    predicted_probs = model.predict_one(attack_image)
    predicted_class = np.argmax(predicted_probs)
    actual_class = y_test[img_id, 0]
    # helper.plot_image(attack_image, actual_class, class_names, predicted_class)

    success = predicted_class != actual_class
    
    return [(attack_result.x[0], attack_result.x[1], attack_result.x[2], attack_result.x[3], attack_result.x[4]), success]

# %%
def sensitive_pixel_sorting(image_id):
    img = x_test[image_id].copy()
    target_class = y_test[image_id, 0]

    diff_list = [[0,0,0]]

    prior_confidence =  model.predict_one(img)[target_class]

    rgb = [0, 0, 0]
    
    sensitive_list_size = 30

    for x in range(32):
        for y in range(32):

          for i in range(3):
              if img[x][y][i] >= 128:
                rgb[i] = 0
              else:
                rgb[i] = 255

          pixel = np.array([x, y,  rgb[0], rgb[1], rgb[2]])
          perturbed_image = perturb_image(pixel, img)
          
          after_confidence =  model.predict_one(perturbed_image)[target_class]
          diff_confidence = abs(after_confidence - prior_confidence)

          if diff_confidence > 0:
              for diff_index in range(len(diff_list)):
                  if diff_confidence >= diff_list[diff_index][2]:
                      diff_list.insert(diff_index, [x, y, diff_confidence])
                      if (len(diff_list) > sensitive_list_size):
                          diff_list.pop()
                      break
    return diff_list

# %%
def attack_success(x, img, target_class, model, targeted_attack=False, verbose=False):
    # Perturb the image with the given pixel(s) and get the prediction of the model
    attack_image = perturb_image(x, img)

    confidence = model.predict(attack_image)[0] # attack_image가 배열이다. 그 중 하나를 리턴.
    predicted_class = np.argmax(confidence) # 그 중 최댓값을 고른다..
    
    # If the prediction is what we want (misclassification or 
    # targeted classification), return True
    if verbose:
        print('Confidence:', confidence[target_class])
    if ((targeted_attack and predicted_class == target_class) or
        (not targeted_attack and predicted_class != target_class)):
        return True
    # NOTE: return None otherwise (not False), due to how Scipy handles its callback function

# %%
image_id_list = [16,20, 25, 87, 384, 520]
models = [lenet, pure_cnn, net_in_net, resnet, densenet, wide_resnet]
image_id = 16
pixels = 1 # Number of pixels to attack
model = resnet
# for i in range(len(image_id_list)):
time_list = [[0]*len(models)] 
for i in range(3):
    for j in range(len(models)):
        model = models[j]
        print(models[j])
        sen_list = sensitive_pixel_sorting(image_id_list[i])
        # model = models[j]
        # print(sen_list)
        print(len(sen_list))
        list_num = 0
        start = time.time()
        # _ = my_attack_3(image_id, model, pixel_count=pixels, maxiter = 5, popsize = 50, verbose = True)
        
        _ = Algorithm1(image_id, models[j], sen_list)
        end = time.time()
        print(f"{end - start:.6f} sec")
        time_list.append(end-start)
    print("image_id : ",image_id)
    print(time_list)
    time_list.clear()
# Out:
# <networks.lenet.LeNet object at 0x000001F88EA92370>
# 30
# pixel coordinate : 24, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 6
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 5
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 6
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 19, 23
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 32.846380 sec
# <networks.pure_cnn.PureCnn object at 0x000001F8A6F8C910>
# 30
# pixel coordinate : 1, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 1, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 1, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 2, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 3, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 6
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 3, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 4, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 2, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 4, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 3, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 2, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 3, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 5, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 0, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 0, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 30, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 2, 6
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 0, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 1, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 1, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 2, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 37.312512 sec
# <networks.network_in_network.NetworkInNetwork object at 0x000001F8A5E5F970>
# 30
# pixel coordinate : 9, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  155.0
# alpha_min :  130
# alpha :  140.0
# alpha_min :  130
# alpha :  132.0
# alpha_min :  130
# pixel coordinate : 5, 21
# alpha :  128
# alpha_min :  1
# alpha :  62.0
# alpha_min :  1
# alpha :  94.0
# alpha_min :  64.0
# pixel coordinate : 8, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  156.0
# alpha_min :  130
# alpha :  141.0
# alpha_min :  130
# pixel coordinate : 4, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  157.0
# alpha_min :  130
# pixel coordinate : 3, 25
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 7, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 23
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 23
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  156.0
# alpha_min :  130
# pixel coordinate : 13, 23
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 6
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 6
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 9, 6
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 1, 23
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 5, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 4, 26
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 6
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 39.187350 sec
# <networks.resnet.ResNet object at 0x000001F8A5C2CA60>
# 30
# pixel coordinate : 5, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 5, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 3, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 2, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 7, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 7, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  154.0
# alpha_min :  130
# pixel coordinate : 4, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 5, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 4, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 4, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 5, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 3, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 4, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 1, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 3, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 7, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 19, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 37.013890 sec
# <networks.densenet.DenseNet object at 0x000001F899CB09D0>
# 30
# pixel coordinate : 16, 15
# alpha :  128
# alpha_min :  1
# alpha :  63.0
# alpha_min :  1
# alpha :  31.0
# alpha_min :  1
# alpha :  47.0
# alpha_min :  33.0
# pixel coordinate : 14, 18
# alpha :  128
# alpha_min :  1
# alpha :  61.0
# alpha_min :  1
# alpha :  92.0
# alpha_min :  63.0
# pixel coordinate : 15, 17
# alpha :  128
# alpha_min :  1
# alpha :  63.0
# alpha_min :  1
# alpha :  95.0
# alpha_min :  65.0
# alpha :  77.0
# alpha_min :  65.0
# alpha :  68.0
# alpha_min :  65.0
# pixel coordinate : 14, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  155.0
# alpha_min :  130
# alpha :  134.0
# alpha_min :  130
# alpha :  130.0
# alpha_min :  130
# pixel coordinate : 15, 15
# alpha :  128
# alpha_min :  1
# alpha :  57.0
# alpha_min :  1
# alpha :  86.0
# alpha_min :  59.0
# alpha :  70.0
# alpha_min :  59.0
# alpha :  63.0
# alpha_min :  59.0
# pixel coordinate : 14, 17
# alpha :  128
# alpha_min :  1
# alpha :  63.0
# alpha_min :  1
# alpha :  31.0
# alpha_min :  1
# alpha :  47.0
# alpha_min :  33.0
# pixel coordinate : 17, 15
# alpha :  128
# alpha_min :  1
# alpha :  58.0
# alpha_min :  1
# alpha :  87.0
# alpha_min :  60.0
# alpha :  68.0
# alpha_min :  60.0
# alpha :  62.0
# alpha_min :  60.0
# alpha :  60.0
# alpha_min :  60.0
# pixel coordinate : 14, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  158.0
# alpha_min :  130
# pixel coordinate : 15, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  159.0
# alpha_min :  130
# pixel coordinate : 16, 14
# alpha :  128
# alpha_min :  1
# alpha :  61.0
# alpha_min :  1
# alpha :  92.0
# alpha_min :  63.0
# pixel coordinate : 15, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 17
# alpha :  128
# alpha_min :  1
# alpha :  60.0
# alpha_min :  1
# alpha :  91.0
# alpha_min :  62.0
# alpha :  73.0
# alpha_min :  62.0
# pixel coordinate : 15, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  156.0
# alpha_min :  130
# pixel coordinate : 16, 16
# alpha :  128
# alpha_min :  1
# alpha :  57.0
# alpha_min :  1
# alpha :  86.0
# alpha_min :  59.0
# alpha :  71.0
# alpha_min :  59.0
# pixel coordinate : 16, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 16
# alpha :  128
# alpha_min :  1
# alpha :  56.0
# alpha_min :  1
# alpha :  85.0
# alpha_min :  58.0
# pixel coordinate : 10, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 17, 14
# alpha :  128
# alpha_min :  1
# alpha :  60.0
# alpha_min :  1
# alpha :  90.0
# alpha_min :  62.0
# pixel coordinate : 14, 23
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 16, 13
# alpha :  128
# alpha_min :  1
# alpha :  63.0
# alpha_min :  1
# alpha :  95.0
# alpha_min :  65.0
# alpha :  78.0
# alpha_min :  65.0
# pixel coordinate : 17, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 14
# alpha :  128
# alpha_min :  1
# alpha :  60.0
# alpha_min :  1
# alpha :  91.0
# alpha_min :  62.0
# pixel coordinate : 15, 13
# alpha :  128
# alpha_min :  1
# alpha :  61.0
# alpha_min :  1
# alpha :  92.0
# alpha_min :  63.0
# pixel coordinate : 14, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  159.0
# alpha_min :  130
# alpha :  136.0
# alpha_min :  130
# pixel coordinate : 12, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 17, 13
# alpha :  128
# alpha_min :  1
# alpha :  62.0
# alpha_min :  1
# alpha :  93.0
# alpha_min :  64.0
# pixel coordinate : 13, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 23
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  157.0
# alpha_min :  130
# pixel coordinate : 10, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 63.217250 sec
# <networks.wide_resnet.WideResNet object at 0x000001F899CB05E0>
# 30
# pixel coordinate : 14, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  160.0
# alpha_min :  130
# pixel coordinate : 14, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 17, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  160.0
# alpha_min :  130
# pixel coordinate : 16, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 18, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 17, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 19, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 19, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 17, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 16, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 18, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 17, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 18, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 19, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 16, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 16, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 50.186423 sec
# image_id :  16
# [[0, 0, 0, 0, 0, 0], 32.84638047218323, 37.312512159347534, 39.18734955787659, 37.01389026641846, 63.21725010871887, 50.18642258644104]
# <networks.lenet.LeNet object at 0x000001F88EA92370>
# 30
# pixel coordinate : 15, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 9, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 6
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 16, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 16, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 25
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 16, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 17, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 9, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 34.015740 sec
# <networks.pure_cnn.PureCnn object at 0x000001F8A6F8C910>
# 30
# pixel coordinate : 9, 27
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 9, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 9, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 27
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 7
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 9, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 9, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 25
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 25
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 40.606384 sec
# <networks.network_in_network.NetworkInNetwork object at 0x000001F8A5E5F970>
# 30
# pixel coordinate : 15, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 16, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 16, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 5
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 27
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 7, 26
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 5
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 16, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 4, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 4
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 39.896554 sec
# <networks.resnet.ResNet object at 0x000001F8A5C2CA60>
# 30
# pixel coordinate : 24, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 23
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 18, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 5, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 5
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 4, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 6, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 5, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 4
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 19, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 38.533411 sec
# <networks.densenet.DenseNet object at 0x000001F899CB09D0>
# 30
# pixel coordinate : 13, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 23
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  159.0
# alpha_min :  130
# pixel coordinate : 12, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  158.0
# alpha_min :  130
# pixel coordinate : 10, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 19, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 9, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 9, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 23
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 17
# alpha :  128
# alpha_min :  1
# alpha :  63.0
# alpha_min :  1
# alpha :  95.0
# alpha_min :  65.0
# pixel coordinate : 12, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 25
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 18, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 25
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 13
# alpha :  128
# alpha_min :  1
# alpha :  60.0
# alpha_min :  1
# alpha :  91.0
# alpha_min :  62.0
# pixel coordinate : 21, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 18
# alpha :  128
# alpha_min :  1
# alpha :  59.0
# alpha_min :  1
# alpha :  89.0
# alpha_min :  61.0
# pixel coordinate : 20, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 17
# alpha :  128
# alpha_min :  1
# alpha :  63.0
# alpha_min :  1
# alpha :  95.0
# alpha_min :  65.0
# alpha :  79.0
# alpha_min :  65.0
# alpha :  71.0
# alpha_min :  65.0
# pixel coordinate : 22, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 61.106437 sec
# <networks.wide_resnet.WideResNet object at 0x000001F899CB05E0>
# 30
# pixel coordinate : 12, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 7, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 16, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 52.887642 sec
# image_id :  16
# [34.015740156173706, 40.60638403892517, 39.896554470062256, 38.53341102600098, 61.10643744468689, 52.88764190673828]
# <networks.lenet.LeNet object at 0x000001F88EA92370>
# 30
# pixel coordinate : 17, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 16, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 17, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 19, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 18, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 5, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 26
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 37.858174 sec
# <networks.pure_cnn.PureCnn object at 0x000001F8A6F8C910>
# 30
# pixel coordinate : 28, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 30, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 30, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 9, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 24
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 45.521979 sec
# <networks.network_in_network.NetworkInNetwork object at 0x000001F8A5E5F970>
# 30
# pixel coordinate : 25, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 19, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 20
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 9, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 19, 5
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 7, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  157.0
# alpha_min :  130
# alpha :  141.0
# alpha_min :  130
# pixel coordinate : 6, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 5
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 23
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 5
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 18, 4
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  156.0
# alpha_min :  130
# pixel coordinate : 10, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 7, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 19, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 44.169937 sec
# <networks.resnet.ResNet object at 0x000001F8A5C2CA60>
# 30
# pixel coordinate : 28, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 17, 31
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 30, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 30
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 16, 31
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 30, 28
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 30, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 30, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 26
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 28
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 43.892276 sec
# <networks.densenet.DenseNet object at 0x000001F899CB09D0>
# 30
# pixel coordinate : 27, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 18, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 20, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 26, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 13
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 23, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 30, 22
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 17, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 24, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 9
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 30, 21
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 18, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 28, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 21, 11
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 22, 12
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 29, 10
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 62.617373 sec
# <networks.wide_resnet.WideResNet object at 0x000001F899CB05E0>
# 30
# pixel coordinate : 26, 15
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 12, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 15, 6
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 5, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 6
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  155.0
# alpha_min :  130
# pixel coordinate : 12, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 10, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 9, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 13, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 18, 6
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 27, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 19, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 17, 6
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 18, 8
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 3, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 7, 16
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 25, 14
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 5
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# alpha :  158.0
# alpha_min :  130
# pixel coordinate : 13, 19
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 8, 18
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 14, 4
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 11, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# pixel coordinate : 2, 17
# alpha :  128
# alpha_min :  1
# alpha :  192
# alpha_min :  130
# 58.614268 sec
# image_id :  16
# [37.85817360877991, 45.521979331970215, 44.169936656951904, 43.89227628707886, 62.61737251281738, 58.61426758766174]
